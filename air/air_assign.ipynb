# %%
import pandas as pd
import os
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## 주제
# 1. 전국 계절별 도시대기 분석
# 2. 노원구 9월 22일 차 없는 거리 분석

# %% [markdown]
# ### 전체 파일 파악

# %% [markdown]
# 1개 파일 체크

# %%
proto = pd.read_excel('2023_air/2023년 1월.xlsx')
proto.head()
# Out:
#       지역     망   측정소코드 측정소명        측정일시    SO2   CO     O3    NO2  PM10  PM25  \
# 0  서울 중구  도시대기  111121   중구  2023010101  0.004  0.8  0.004  0.055  57.0  52.0
# 1  서울 중구  도시대기  111121   중구  2023010102  0.004  0.8  0.004  0.051  65.0  60.0
# 2  서울 중구  도시대기  111121   중구  2023010103  0.004  0.8  0.005  0.048  73.0  63.0
# 3  서울 중구  도시대기  111121   중구  2023010104  0.004  0.7  0.014  0.032  76.0  71.0
# 4  서울 중구  도시대기  111121   중구  2023010105  0.004  0.7  0.021  0.021  78.0  73.0
#
#               주소
# 0  서울 중구 덕수궁길 15
# 1  서울 중구 덕수궁길 15
# 2  서울 중구 덕수궁길 15
# 3  서울 중구 덕수궁길 15
# 4  서울 중구 덕수궁길 15

# %% [markdown]
# 측정되지 않은 공기질 파악하기

# %%
elements = proto.columns[5:11]
for ele in elements:
    null_cnt = proto.isnull().value_counts(ele)
    print(null_cnt)
# Out:
# SO2
# False    459194
# True      18190
# Name: count, dtype: int64
# CO
# False    459658
# True      17726
# Name: count, dtype: int64
# O3
# False    463184
# True      14200
# Name: count, dtype: int64
# NO2
# False    462536
# True      14848
# Name: count, dtype: int64
# PM10
# False    460913
# True      16471
# Name: count, dtype: int64
# PM25
# False    455589
# True      21795
# Name: count, dtype: int64

# %%
proto[elements].isnull().value_counts()
# Out:
# SO2    CO     O3     NO2    PM10   PM25
# False  False  False  False  False  False    435202
#                                    True       9515
# True   True   True   True   True   True       9222
#        False  False  False  False  False      3875
# False  False  False  False  True   False      3566
#        True   False  False  False  False      3066
#        False  False  True   False  False      2563
#                      False  True   True       2442
# True   True   False  False  False  False      2202
# False  False  True   False  False  False      1925
# True   True   True   True   False  False      1620
#                             True   False       808
# False  True   True   False  False  False       157
#        False  True   True   False  False       146
#        True   False  True   False  False       133
#                      False  False  True        117
# True   True   True   False  False  True         81
#        False  False  False  True   False        71
# False  False  False  True   False  True         70
#        True   False  False  True   False        59
# True   False  False  True   False  False        51
#        True   True   True   False  True         49
# False  False  False  True   True   True         47
# True   True   False  False  True   True         47
# False  False  True   False  False  True         46
#        True   False  False  True   True         34
# True   False  False  False  False  True         32
#        True   True   False  True   True         29
# False  True   True   True   True   False        28
# True   True   False  True   True   False        23
#        False  True   True   False  False        22
# False  False  False  True   True   False        20
# True   False  False  False  True   True         17
#        True   False  False  True   False        15
# False  True   True   True   False  False        14
#        False  True   True   True   True         11
#                      False  True   False         9
# True   True   False  False  False  True          6
# False  False  True   False  True   True          6
#        True   True   False  False  True          6
#        False  True   True   True   False         6
# True   False  True   False  False  False         5
#        True   False  True   True   True          4
#        False  False  True   False  True          4
#        True   True   False  False  False         2
# False  False  True   True   False  True          2
#        True   True   False  True   True          2
# True   False  False  True   True   True          2
#               True   True   True   True          1
#                      False  True   False         1
#                             False  True          1
# False  True   False  True   False  True          1
#               True   True   True   True          1
# Name: count, dtype: int64

# %% [markdown]
# #### 전처리
# - 측정일시 -> 월, 일, 시로 열 분리
# - 누락값 체크

# %% [markdown]
# 1. 누락값 및 데이터프레임 merge

# %%
direc = '2023_air/'

data = pd.DataFrame()

for file in os.listdir(direc):
    if file.endswith('xlsx'):
        fileloc = os.path.join(direc,file)
        
        with open(fileloc) as f:
            monthly = pd.read_excel(fileloc)
            print("null 제거 이전", len(monthly))
            monthly.dropna(inplace=True)
            print("null 제거 후", len(monthly))
            data = pd.concat([data,monthly])

data
# Out:
# null 제거 이전 481368
# null 제거 후 411872
# null 제거 이전 469104
# null 제거 후 418960
# null 제거 이전 465097
# null 제거 후 411948
# null 제거 이전 484344
# null 제거 후 431264
# null 제거 이전 485088
# null 제거 후 431591
# null 제거 이전 464136
# null 제거 후 427405
# null 제거 이전 480288
# null 제거 후 429238
# null 제거 이전 468120
# null 제거 후 414698
# null 제거 이전 477384
# null 제거 후 435202
# null 제거 이전 483096
# null 제거 후 413186
# null 제거 이전 477840
# null 제거 후 440844
# null 제거 이전 431424
# null 제거 후 396636
#             지역       망   측정소코드 측정소명        측정일시     SO2    CO      O3     NO2  \
# 0        서울 중구    도시대기  111121   중구  2023070101  0.0027  0.41  0.0249  0.0188
# 1        서울 중구    도시대기  111121   중구  2023070102  0.0030  0.42  0.0263  0.0163
# 2        서울 중구    도시대기  111121   중구  2023070103  0.0027  0.42  0.0218  0.0192
# 3        서울 중구    도시대기  111121   중구  2023070104  0.0028  0.41  0.0131  0.0214
# 4        서울 중구    도시대기  111121   중구  2023070105  0.0021  0.43  0.0131  0.0160
# ...        ...     ...     ...  ...         ...     ...   ...     ...     ...
# 431419  인천 옹진군  국가배경농도  831495   울도  2023022820  0.0014  0.27  0.0528  0.0096
# 431420  인천 옹진군  국가배경농도  831495   울도  2023022821  0.0013  0.26  0.0548  0.0070
# 431421  인천 옹진군  국가배경농도  831495   울도  2023022822  0.0016  0.26  0.0471  0.0122
# 431422  인천 옹진군  국가배경농도  831495   울도  2023022823  0.0014  0.27  0.0451  0.0125
# 431423  인천 옹진군  국가배경농도  831495   울도  2023022824  0.0019  0.28  0.0304  0.0225
#
#         PM10  PM25                   주소
# 0       21.0  19.0        서울 중구 덕수궁길 15
# 1       18.0  15.0        서울 중구 덕수궁길 15
# 2       24.0  21.0        서울 중구 덕수궁길 15
# 3       25.0  19.0        서울 중구 덕수궁길 15
# 4       25.0  21.0        서울 중구 덕수궁길 15
# ...      ...   ...                  ...
# 431419  37.0  23.0  인천 옹진군 덕적면 울도리 85번지
# 431420  33.0  24.0  인천 옹진군 덕적면 울도리 85번지
# 431421  41.0  19.0  인천 옹진군 덕적면 울도리 85번지
# 431422  39.0  20.0  인천 옹진군 덕적면 울도리 85번지
# 431423  49.0  24.0  인천 옹진군 덕적면 울도리 85번지
#
# [5062844 rows x 12 columns]

# %% [markdown]
# month, day, time으로 새로운 필드 생성

# %%
data['측정일시'] = data['측정일시'].astype(str).str.replace(r'24$', '00', regex=True)

data['datetime'] = pd.to_datetime(data['측정일시'], format='%Y%m%d%H', errors='coerce')
data['month'] = data['datetime'].dt.month
data['day'] = data['datetime'].dt.day
data['hour'] = data['datetime'].dt.hour

# %% [markdown]
# ### 주제1 전국의 계절별 대기오염 원인 분석

# %%
country= data.groupby(['month']).agg(
        SO2_mean = pd.NamedAgg(column='SO2',aggfunc='mean'),
        O3_mean = pd.NamedAgg(column='O3',aggfunc='mean'),
        NO2_mean = pd.NamedAgg(column='NO2',aggfunc='mean'),
        PM10_mean = pd.NamedAgg(column='PM10',aggfunc='mean'),
        PM25_mean = pd.NamedAgg(column='PM25',aggfunc='mean'),
    )

country
# Out:
#        SO2_mean   O3_mean  NO2_mean  PM10_mean  PM25_mean
# month
# 1      0.002726  0.021932  0.019962  45.386391  24.416501
# 2      0.002786  0.026891  0.020464  43.803727  28.279024
# 3      0.002775  0.038101  0.018501  64.471641  27.372898
# 4      0.002408  0.041154  0.013022  66.256974  21.419370
# 5      0.002486  0.042854  0.012349  37.713583  17.459093
# 6      0.002403  0.045751  0.010486  26.787311  15.256122
# 7      0.002384  0.032029  0.009552  24.506274  13.995338
# 8      0.002394  0.031306  0.008966  21.885403  12.418959
# 9      0.002291  0.030604  0.010118  21.596772  11.533444
# 10     0.002423  0.029580  0.013926  28.970111  15.379475
# 11     0.002550  0.026422  0.015342  29.847752  16.750425
# 12     0.002625  0.023315  0.018506  36.021847  21.553714

# %%
sns.set_theme(style="darkgrid")

f, axes = plt.subplots(1,2,figsize=(13, 5))
sns.despine(f)

sns.lineplot(
    data = country[["PM10_mean","PM25_mean"]],
        palette=['red','brown'],
        linestyle="--",
        ax=axes[0]
    )

sns.lineplot(
    data=country[["SO2_mean","O3_mean","NO2_mean"]],
    linestyle='dotted',
    ax = axes[1]
    )
# Out:
# <Axes: xlabel='month'>

# %% [markdown]
# -> 미세먼지는 2월에 급격하게 상승하여 4월까지 높게 나타남 (봄에 미세먼지 주의)
# 오존은 여름에 증가함을 확인할 수 있다.

# %% [markdown]
# ### 주제2: 차 없는날 9월22일 -> NO2 비교

# %% [markdown]
# 노원구 측정주소가 있는지 확인

# %%
filter_add = data.set_index('주소')
nowon = filter_add.filter(like="노원",axis=0)
nowon
# Out:
#                     지역      망   측정소코드 측정소명        측정일시     SO2    CO      O3  \
# 주소
# 서울 노원구 상계로 118  서울 노원구   도시대기  111311  노원구  2023070101  0.0025  0.58  0.0132
# 서울 노원구 상계로 118  서울 노원구   도시대기  111311  노원구  2023070102  0.0027  0.54  0.0149
# 서울 노원구 상계로 118  서울 노원구   도시대기  111311  노원구  2023070103  0.0029  0.51  0.0151
# 서울 노원구 상계로 118  서울 노원구   도시대기  111311  노원구  2023070104  0.0026  0.47  0.0153
# 서울 노원구 상계로 118  서울 노원구   도시대기  111311  노원구  2023070105  0.0028  0.41  0.0204
# ...                ...    ...     ...  ...         ...     ...   ...     ...
# 서울 노원구 화랑로 429  서울 노원구  도로변대기  111312  화랑로  2023022820  0.0030  0.41  0.0243
# 서울 노원구 화랑로 429  서울 노원구  도로변대기  111312  화랑로  2023022821  0.0029  0.44  0.0215
# 서울 노원구 화랑로 429  서울 노원구  도로변대기  111312  화랑로  2023022822  0.0030  0.45  0.0154
# 서울 노원구 화랑로 429  서울 노원구  도로변대기  111312  화랑로  2023022823  0.0029  0.46  0.0145
# 서울 노원구 화랑로 429  서울 노원구  도로변대기  111312  화랑로  2023022800  0.0029  0.45  0.0150
#
#                    NO2  PM10  PM25            datetime  month  day  hour
# 주소
# 서울 노원구 상계로 118  0.0211  47.0  32.0 2023-07-01 01:00:00      7    1     1
# 서울 노원구 상계로 118  0.0164  44.0  28.0 2023-07-01 02:00:00      7    1     2
# 서울 노원구 상계로 118  0.0148  36.0  23.0 2023-07-01 03:00:00      7    1     3
# 서울 노원구 상계로 118  0.0125  38.0  23.0 2023-07-01 04:00:00      7    1     4
# 서울 노원구 상계로 118  0.0094  29.0  18.0 2023-07-01 05:00:00      7    1     5
# ...                ...   ...   ...                 ...    ...  ...   ...
# 서울 노원구 화랑로 429  0.0335  27.0  17.0 2023-02-28 20:00:00      2   28    20
# 서울 노원구 화랑로 429  0.0372  28.0  16.0 2023-02-28 21:00:00      2   28    21
# 서울 노원구 화랑로 429  0.0461  25.0  15.0 2023-02-28 22:00:00      2   28    22
# 서울 노원구 화랑로 429  0.0423  29.0  18.0 2023-02-28 23:00:00      2   28    23
# 서울 노원구 화랑로 429  0.0394  27.0  17.0 2023-02-28 00:00:00      2   28     0
#
# [16950 rows x 15 columns]

# %% [markdown]
# 노원구 시간별 평균 NO2

# %%
nowon = data[(data["지역"]=="서울 노원구")]
nowon_avg = nowon.groupby(['hour']).agg(
        SO2_a = pd.NamedAgg(column='SO2',aggfunc='mean'),
        O3_a = pd.NamedAgg(column='O3',aggfunc='mean'),
        NO2_a = pd.NamedAgg(column='NO2',aggfunc='mean'),
        PM10_a = pd.NamedAgg(column='PM10',aggfunc='mean'),
        PM25_a = pd.NamedAgg(column='PM25',aggfunc='mean'),
    )

# %%
nowon = data[(data["지역"]=="서울 노원구")&(data["month"]==11)&(data["day"]==4)]
nowon_922 = nowon.groupby(['hour']).agg(
        SO2= pd.NamedAgg(column='SO2',aggfunc='mean'),
        O3 = pd.NamedAgg(column='O3',aggfunc='mean'),
        NO2 = pd.NamedAgg(column='NO2',aggfunc='mean'),
        PM10 = pd.NamedAgg(column='PM10',aggfunc='mean'),
        PM25 = pd.NamedAgg(column='PM25',aggfunc='mean'),
    )

# %%
compare = nowon_avg[["NO2_a"]].merge(nowon_922[["NO2"]],on=nowon_avg.index,how='left')
compare.set_index('key_0',inplace=True)
compare
# Out:
#           NO2_a      NO2
# key_0
# 0      0.026205  0.01275
# 1      0.023955  0.02040
# 2      0.021915  0.01560
# 3      0.020856  0.01235
# 4      0.020466  0.01205
# 5      0.021913  0.01590
# 6      0.025932  0.01780
# 7      0.030108  0.02225
# 8      0.030883  0.02130
# 9      0.029921  0.02185
# 10     0.028009  0.02345
# 11     0.025765  0.02475
# 12     0.023512  0.01870
# 13     0.021971  0.01520
# 14     0.021562  0.01405
# 15     0.021914  0.01630
# 16     0.022070  0.01595
# 17     0.023562  0.01920
# 18     0.026071  0.01855
# 19     0.027859  0.01785
# 20     0.028604  0.01940
# 21     0.028300  0.01445
# 22     0.028096  0.01625
# 23     0.027806  0.01370

# %%
sns.set_theme(style="whitegrid")

f, axes = plt.subplots(figsize=(9, 5))
sns.despine(f)

sns.lineplot(
    data = compare)
# Out:
# <Axes: xlabel='key_0'>

# %% [markdown]
# 차 없는 거리: 차량 배출가스 줄어든 것으로 확인

# %%
compare2 = nowon_avg.merge(nowon_922,on=nowon_avg.index,how='left')
compare2.set_index('key_0',inplace=True)
compare2
# Out:
#           SO2_a      O3_a     NO2_a     PM10_a     PM25_a      SO2       O3  \
# key_0
# 0      0.002639  0.020572  0.026205  39.110014  19.678420  0.00250  0.02080
# 1      0.002587  0.020394  0.023955  39.843441  20.864598  0.00245  0.01235
# 2      0.002539  0.020370  0.021915  37.159605  19.210452  0.00275  0.01420
# 3      0.002503  0.019588  0.020856  37.738397  20.689170  0.00260  0.01705
# 4      0.002475  0.018410  0.020466  35.666667  18.995708  0.00265  0.01460
# 5      0.002488  0.016321  0.021913  37.042674  20.479374  0.00250  0.01220
# 6      0.002556  0.013462  0.025932  36.005666  19.230878  0.00255  0.01060
# 7      0.002663  0.011188  0.030108  38.471086  21.076164  0.00275  0.00590
# 8      0.002712  0.011926  0.030883  37.519553  19.687151  0.00275  0.00720
# 9      0.002757  0.015295  0.029921  39.364017  21.027894  0.00295  0.00770
# 10     0.002837  0.020343  0.028009  38.812500  20.256944  0.00295  0.01015
# 11     0.002881  0.026294  0.025765  42.091922  22.221448  0.00275  0.01190
# 12     0.002914  0.032202  0.023512  41.109551  21.101124  0.00270  0.01910
# 13     0.002910  0.037135  0.021971  41.072046  21.409222  0.00250  0.02675
# 14     0.002893  0.040722  0.021562  38.176046  19.489177  0.00265  0.02930
# 15     0.002887  0.042621  0.021914  39.203488  20.168605  0.00235  0.03085
# 16     0.002865  0.043229  0.022070  38.312321  19.154728  0.00245  0.02910
# 17     0.002845  0.041583  0.023562  39.770655  20.273504  0.00270  0.02380
# 18     0.002834  0.037665  0.026071  38.314204  18.784792  0.00240  0.02015
# 19     0.002817  0.033178  0.027859  40.275466  20.489240  0.00240  0.01905
# 20     0.002812  0.029236  0.028604  39.345557  19.875882  0.00260  0.01705
# 21     0.002773  0.026154  0.028300  41.098592  21.425352  0.00230  0.01965
# 22     0.002741  0.023770  0.028096  39.452883  19.952180  0.00245  0.02070
# 23     0.002705  0.021618  0.027806  40.817927  21.364146  0.00255  0.02080
#
#            NO2  PM10  PM25
# key_0
# 0      0.01275  10.5   4.5
# 1      0.02040  57.0  27.0
# 2      0.01560  60.0  23.0
# 3      0.01235  73.0  26.0
# 4      0.01205  78.5  23.5
# 5      0.01590  77.5  24.0
# 6      0.01780  76.5  22.5
# 7      0.02225  73.0  24.0
# 8      0.02130  62.5  21.5
# 9      0.02185  59.5  19.5
# 10     0.02345  56.0  19.0
# 11     0.02475  59.5  18.5
# 12     0.01870  52.0  16.5
# 13     0.01520  38.5  14.5
# 14     0.01405  33.0  14.5
# 15     0.01630  36.5  15.0
# 16     0.01595  36.0  17.5
# 17     0.01920  31.0  13.5
# 18     0.01855  22.0  10.0
# 19     0.01785  18.0   8.0
# 20     0.01940  15.0   6.5
# 21     0.01445  14.0   9.0
# 22     0.01625  10.5   5.0
# 23     0.01370  13.0   8.5

# %%
sns.set_theme(style="darkgrid")

f, axes = plt.subplots(1,2,figsize=(9, 5))
sns.despine(f)

sns.lineplot(
    data = compare2[["PM10_a","PM25_a","PM10","PM25"]],
    ax = axes[0])


sns.lineplot(
    data = compare2[["SO2_a","O3_a","SO2","O3"]],
    ax=axes[1])
# Out:
# <Axes: xlabel='key_0'>

# %% [markdown]
# -> NO2를 제외한 대기 질 측정
# - 미세먼지는 오히려 증가
# - O3 또한 감소
